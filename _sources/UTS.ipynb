# %% [markdown]
# # **UTS**

# %%
# !pip install numpy 
# !pip install pandas
# !pip install nltk
# !pip install sastrawi
# !pip install PySastrawi
# !pip install regex
# !pip instal swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (1.22.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.4.4)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.8.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk) (1.1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk) (4.65.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 KB 17.7 MB/s eta 0:00:00
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PySastrawi
#   Downloading PySastrawi-1.2.0-py2.py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.6/210.6 KB 16.5 MB/s eta 0:00:00
# Installing collected packages: PySastrawi
# Successfully installed PySastrawi-1.2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (2022.10.31)
# ERROR: unknown command "instal" - maybe you meant "install"

# %%
import pandas as pd
import numpy as np
import nltk
import string
import regex as re

# %%
data = pd.read_excel("/content/drive/MyDrive/prosaindata/tugas/Data_TA.xlsx")
data.head()
# Out:
#            NPM                                              Judul  \
# 0  40411100468  PERANCANGAN DAN IMPLEMENTASI SISTEM DATABASE T...
# 1  40411100476  APLIKASI KONTROL DAN MONITORING JARINGAN KOMPU...
# 2  40411100480  RANCANG BANGUN APLIKASI PROXY SERVER UNTUKENKR...
# 3  70411100070  SISTEM PENDUKUNG KEPUTUSAN OPTIMASI PENJADWALA...
# 4  80411100115  SISTEM AUGMENTED REALITY ANIMASI BENDA BERGERA...
#
#                                              Abstrak               Prodi  \
# 0  Sistem  informasi  akademik  (SIAKAD) merupaka...  Teknik Informatika
# 1  Berjalannya koneksi jaringan komputer dengan l...  Teknik Informatika
# 2  Web server adalah sebuah perangkat lunak serve...  Teknik Informatika
# 3  Penjadwalan  kuliah  di  Perguruan  Tinggi  me...  Teknik Informatika
# 4  Seiring perkembangan teknologi yang ada diduni...  Teknik Informatika
#
#        Label
# 0        RPL
# 1        RPL
# 2        RPL
# 3  komputasi
# 4  komputasi

# %%
#cekdata null
data.isnull().sum()
# Out:
# NPM         0
# Judul       6
# Abstrak    25
# Prodi       0
# Label      43
# dtype: int64

# %%
#drop data kosong
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# NPM        0
# Judul      0
# Abstrak    0
# Prodi      0
# Label      0
# dtype: int64

# %%
data.count()
# Out:
# NPM        810
# Judul      810
# Abstrak    810
# Prodi      810
# Label      810
# dtype: int64

# %%
data["Label"].value_counts()
# Out:
# komputasi    573
# RPL          198
# PBA           39
# Name: Label, dtype: int64

# %% [markdown]
# ### Text Prepocessing

# %%
#import library
import re
import string

# %%
#text cleaning
def text_cleaning(text):
  #hapus url
  text = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});').sub('', str(text))
 
  #ubah huruf kecil
  text = text.lower()

  #hapus karakter awal dan akhir
  text = re.strip()

  #hapus tanda hubung(punctuation)
  text = re.compile('<.*?>').sub("",text)

  #hapus karakter spesial
  text =re.compile("[%s]" % re.escape(string.punctuation))
  
  #hapus spasi ganda
  text = re.sub("\s+","",text)

  #hapus angka
  text = re.sub(r"\[[0-9]*\]","",text)
  text = re.sub(r"[^\w\s]","",str(text).lower().strip())
  text = re.sub(r"\d","",text)
  text = re.sub(r"\s","",text)

  #ubah text nan menjadi whitespace
  text = re.sub("nan","",text)

  return text

# %%
import re

def text_cleaning(text):
  #hapus karakter yang tidak diperlukan
  text = re.sub(r'[^\w\s]','',text)
  
  #hapus angka
  text = re.sub(r'\d+','',text)
  
  #ubah ke huruf kecil
  text = text.lower()
  
  #hapus karakter awal dan akhir
  text = text.strip()
  
  #hapus tanda hubung(punctuation)
  text = re.sub(r'[\-]',' ',text)
  
  #hapus multiple spasi
  text = re.sub(r'\s+',' ',text)
  
  return text

# %%
pip install regex
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (2022.10.31)

# %%
data['Judul'] = data['Judul'].apply(lambda x: text_cleaning(x))
data['Abstrak'] = data['Abstrak'].apply(lambda x: text_cleaning(x))

data.head()
# Out:
#            NPM                                              Judul  \
# 0  40411100468  perancangan dan implementasi sistem database t...
# 1  40411100476  aplikasi kontrol dan monitoring jaringan kompu...
# 2  40411100480  rancang bangun aplikasi proxy server untukenkr...
# 3  70411100070  sistem pendukung keputusan optimasi penjadwala...
# 4  80411100115  sistem augmented reality animasi benda bergera...
#
#                                              Abstrak               Prodi  \
# 0  sistem informasi akademik siakad merupakan sis...  Teknik Informatika
# 1  berjalannya koneksi jaringan komputer dengan l...  Teknik Informatika
# 2  web server adalah sebuah perangkat lunak serve...  Teknik Informatika
# 3  penjadwalan kuliah di perguruan tinggi merupak...  Teknik Informatika
# 4  seiring perkembangan teknologi yang ada diduni...  Teknik Informatika
#
#        Label
# 0        RPL
# 1        RPL
# 2        RPL
# 3  komputasi
# 4  komputasi

# %%
data.to_csv("pta_cleaning.csv")

# %% [markdown]
# #### menghapus nilai kosong

# %%
#ubah empty string menjadi NaN
data = data.replace("",np.nan)

# %%
#cek data kosong
data.isnull().sum()
# Out:
# NPM        0
# Judul      0
# Abstrak    0
# Prodi      0
# Label      0
# dtype: int64

# %%
#hapus data kosong
data.dropna(inplace=True)
len(data)
# Out:
# 810

# %% [markdown]
# #### Menghapus data duplikat

# %% [markdown]
# #### Duplikat data pada kolom judul

# %%
#duplikat pada kolom judul
data[data["Judul"].duplicated()]
# Out:
#               NPM                                              Judul  \
# 728  120411100015  sistem pendukung keputusan pemilihan pemain bo...
#
#                                                Abstrak               Prodi  \
# 728  peningkatan pembinaan permainan bola voli teru...  Teknik Informatika
#
#          Label
# 728  komputasi

# %%
#hapus duplikat
data.drop_duplicates(subset=["Judul"],inplace=True)

#cek data duplikat
data[data["Judul"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [NPM, Judul, Abstrak, Prodi, Label]
# Index: []

# %% [markdown]
# #### Duplikat pada kolom abstrak

# %%
#duplikat pada kolom judul
data[data["Abstrak"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [NPM, Judul, Abstrak, Prodi, Label]
# Index: []

# %%
#hapus duplikat
data.drop_duplicates(subset=["Abstrak"],inplace=True)

#cek data duplikat
data[data["Abstrak"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [NPM, Judul, Abstrak, Prodi, Label]
# Index: []

# %%
#menampilkan hasil preprocessing
data.to_csv("pta-preprocessing.csv")

# %% [markdown]
# ### Tokenization

# %%
from nltk.tokenize import word_tokenize
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Tokenizing Judul
data['judul_tokens'] = data['Judul'].apply(lambda x: word_tokenize(x))
data[["Judul", "judul_tokens"]].head()
# Out:
#                                                Judul  \
# 0  perancangan dan implementasi sistem database t...
# 1  aplikasi kontrol dan monitoring jaringan kompu...
# 2  rancang bangun aplikasi proxy server untukenkr...
# 3  sistem pendukung keputusan optimasi penjadwala...
# 4  sistem augmented reality animasi benda bergera...
#
#                                         judul_tokens
# 0  [perancangan, dan, implementasi, sistem, datab...
# 1  [aplikasi, kontrol, dan, monitoring, jaringan,...
# 2  [rancang, bangun, aplikasi, proxy, server, unt...
# 3  [sistem, pendukung, keputusan, optimasi, penja...
# 4  [sistem, augmented, reality, animasi, benda, b...

# %%
# Tokenizing Abstrak
data['abstrak_tokens'] = data['Abstrak'].apply(lambda x: word_tokenize(x))
data[["Abstrak", "abstrak_tokens"]].head()
# Out:
#                                              Abstrak  \
# 0  sistem informasi akademik siakad merupakan sis...
# 1  berjalannya koneksi jaringan komputer dengan l...
# 2  web server adalah sebuah perangkat lunak serve...
# 3  penjadwalan kuliah di perguruan tinggi merupak...
# 4  seiring perkembangan teknologi yang ada diduni...
#
#                                       abstrak_tokens
# 0  [sistem, informasi, akademik, siakad, merupaka...
# 1  [berjalannya, koneksi, jaringan, komputer, den...
# 2  [web, server, adalah, sebuah, perangkat, lunak...
# 3  [penjadwalan, kuliah, di, perguruan, tinggi, m...
# 4  [seiring, perkembangan, teknologi, yang, ada, ...

# %% [markdown]
# ### Stopwords Removal

# %%
#menghapus kata yang tidak digunakan
from nltk.corpus import stopwords
from itertools import chain
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopword = set(chain(stopwords.words("indonesian"), stopwords.words("english")))

data["judul_tokens"]=data["judul_tokens"].apply(lambda x:[w for w in x if not w in stopword])
data["abstrak_tokens"]=data["abstrak_tokens"].apply(lambda x:[w for w in x if not w in stopword])

# %%
data[["Judul","judul_tokens"]].head()
# Out:
#                                                Judul  \
# 0  perancangan dan implementasi sistem database t...
# 1  aplikasi kontrol dan monitoring jaringan kompu...
# 2  rancang bangun aplikasi proxy server untukenkr...
# 3  sistem pendukung keputusan optimasi penjadwala...
# 4  sistem augmented reality animasi benda bergera...
#
#                                         judul_tokens
# 0  [perancangan, implementasi, sistem, database, ...
# 1  [aplikasi, kontrol, monitoring, jaringan, komp...
# 2  [rancang, bangun, aplikasi, proxy, server, unt...
# 3  [sistem, pendukung, keputusan, optimasi, penja...
# 4  [sistem, augmented, reality, animasi, benda, b...

# %%
data[["Abstrak", "abstrak_tokens"]].head()
# Out:
#                                              Abstrak  \
# 0  sistem informasi akademik siakad merupakan sis...
# 1  berjalannya koneksi jaringan komputer dengan l...
# 2  web server adalah sebuah perangkat lunak serve...
# 3  penjadwalan kuliah di perguruan tinggi merupak...
# 4  seiring perkembangan teknologi yang ada diduni...
#
#                                       abstrak_tokens
# 0  [sistem, informasi, akademik, siakad, sistem, ...
# 1  [berjalannya, koneksi, jaringan, komputer, lan...
# 2  [web, server, perangkat, lunak, server, berfun...
# 3  [penjadwalan, kuliah, perguruan, kompleks, per...
# 4  [seiring, perkembangan, teknologi, didunia, mu...

# %% [markdown]
# ### Stemming

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from tqdm.auto import tqdm
tqdm.pandas()

factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
# Stemming judul
data['judul_tokens'] = data['judul_tokens'].progress_apply(lambda x: stemmer.stem(' '.join(x)).split(' '))
# Out:
#   0%|          | 0/809 [00:00<?, ?it/s]

# %%
#hasil stemming judul
data[["Judul","judul_tokens"]].head()
# Out:
#                                                Judul  \
# 0  perancangan dan implementasi sistem database t...
# 1  aplikasi kontrol dan monitoring jaringan kompu...
# 2  rancang bangun aplikasi proxy server untukenkr...
# 3  sistem pendukung keputusan optimasi penjadwala...
# 4  sistem augmented reality animasi benda bergera...
#
#                                         judul_tokens
# 0  [ancang, implementasi, sistem, database, distr...
# 1  [aplikasi, kontrol, monitoring, jaring, komput...
# 2  [rancang, bangun, aplikasi, proxy, server, unt...
# 3  [sistem, dukung, putus, optimasi, jadwal, mata...
# 4  [sistem, augmented, reality, animasi, benda, g...

# %%
# Stemming abstrak
data['abstrak_tokens'] = data['abstrak_tokens'].progress_apply(lambda x: stemmer.stem(' '.join(x)).split(' '))
# Out:
#   0%|          | 0/809 [00:00<?, ?it/s]

# %%
#hasil stemming abstrak
data[["Abstrak","abstrak_tokens"]].head()
# Out:
#                                              Abstrak  \
# 0  sistem informasi akademik siakad merupakan sis...
# 1  berjalannya koneksi jaringan komputer dengan l...
# 2  web server adalah sebuah perangkat lunak serve...
# 3  penjadwalan kuliah di perguruan tinggi merupak...
# 4  seiring perkembangan teknologi yang ada diduni...
#
#                                       abstrak_tokens
# 0  [sistem, informasi, akademik, siakad, sistem, ...
# 1  [jalan, koneksi, jaring, komputer, lancar, gan...
# 2  [web, server, perangkat, lunak, server, berfun...
# 3  [jadwal, kuliah, guru, kompleks, masalah, vari...
# 4  [iring, kembang, teknologi, dunia, muncul, tek...

# %% [markdown]
# ### Eksport Cleaned Data

# %%
data
# Out:
#               NPM                                              Judul  \
# 0     40411100468  perancangan dan implementasi sistem database t...
# 1     40411100476  aplikasi kontrol dan monitoring jaringan kompu...
# 2     40411100480  rancang bangun aplikasi proxy server untukenkr...
# 3     70411100070  sistem pendukung keputusan optimasi penjadwala...
# 4     80411100115  sistem augmented reality animasi benda bergera...
# ..            ...                                                ...
# 848  160411100032  penerapan algoritma longshort term memory untu...
# 849  160411100182  sistem pencarian teks alquran terjemahan berba...
# 850  160411100077  klasifikasi kompleksitas visual citra sampah m...
# 851  160411100084  identifikasi biner atribut pejalan kaki menggu...
# 852  160411100044  deteksi objek manusia berbasis one stage detec...
#
#                                                Abstrak               Prodi  \
# 0    sistem informasi akademik siakad merupakan sis...  Teknik Informatika
# 1    berjalannya koneksi jaringan komputer dengan l...  Teknik Informatika
# 2    web server adalah sebuah perangkat lunak serve...  Teknik Informatika
# 3    penjadwalan kuliah di perguruan tinggi merupak...  Teknik Informatika
# 4    seiring perkembangan teknologi yang ada diduni...  Teknik Informatika
# ..                                                 ...                 ...
# 848  investasi saham selama ini memiliki resiko ker...  Teknik Informatika
# 849  information retrieval ir merupakan pengambilan...  Teknik Informatika
# 850  klasifikasi citra merupakan proses pengelompok...  Teknik Informatika
# 851  identifikasi atribut pejalan kaki merupakan sa...  Teknik Informatika
# 852  topik deteksi objek telah menarik perhatian ya...  Teknik Informatika
#
#          Label                                       judul_tokens  \
# 0          RPL  [ancang, implementasi, sistem, database, distr...
# 1          RPL  [aplikasi, kontrol, monitoring, jaring, komput...
# 2          RPL  [rancang, bangun, aplikasi, proxy, server, unt...
# 3    komputasi  [sistem, dukung, putus, optimasi, jadwal, mata...
# 4    komputasi  [sistem, augmented, reality, animasi, benda, g...
# ..         ...                                                ...
# 848  komputasi  [terap, algoritma, longshort, term, memory, pr...
# 849        PBA  [sistem, cari, teks, alquran, terjemah, bahasa...
# 850  komputasi  [klasifikasi, kompleksitas, visual, citra, sam...
# 851  komputasi  [identifikasi, biner, atribut, pejal, kaki, ad...
# 852  komputasi  [deteksi, objek, manusia, bas, one, stage, det...
#
#                                         abstrak_tokens
# 0    [sistem, informasi, akademik, siakad, sistem, ...
# 1    [jalan, koneksi, jaring, komputer, lancar, gan...
# 2    [web, server, perangkat, lunak, server, berfun...
# 3    [jadwal, kuliah, guru, kompleks, masalah, vari...
# 4    [iring, kembang, teknologi, dunia, muncul, tek...
# ..                                                 ...
# 848  [investasi, saham, milik, resiko, rugi, dikare...
# 849  [information, retrieval, ir, ambil, informasi,...
# 850  [klasifikasi, citra, proses, kelompok, piksel,...
# 851  [identifikasi, atribut, pejal, kaki, salah, te...
# 852  [topik, deteksi, objek, tarik, perhati, kemban...
#
# [809 rows x 7 columns]

# %%
data["judul_tokens"]=data["judul_tokens"].apply(lambda x: "".join(x))
data["abstrak_tokens"]=data["abstrak_tokens"].apply(lambda x: "".join(x))

data.to_csv("data-pta-cleaned.csv")
