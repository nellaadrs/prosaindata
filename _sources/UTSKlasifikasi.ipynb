# %% [markdown]
# # **UTS Modeling**

# %%
# !pip install numpy
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (1.22.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load Preproced data

# %%
data = pd.read_csv("/content/drive/MyDrive/prosaindata/tugas/data-pta-cleaned.csv",index_col=0)
data.head()
# Out:
#            NPM                                              Judul  \
# 0  40411100468  perancangan dan implementasi sistem database t...
# 1  40411100476  aplikasi kontrol dan monitoring jaringan kompu...
# 2  40411100480  rancang bangun aplikasi proxy server untukenkr...
# 3  70411100070  sistem pendukung keputusan optimasi penjadwala...
# 4  80411100115  sistem augmented reality animasi benda bergera...
#
#                                              Abstrak               Prodi  \
# 0  sistem informasi akademik siakad merupakan sis...  Teknik Informatika
# 1  berjalannya koneksi jaringan komputer dengan l...  Teknik Informatika
# 2  web server adalah sebuah perangkat lunak serve...  Teknik Informatika
# 3  penjadwalan kuliah di perguruan tinggi merupak...  Teknik Informatika
# 4  seiring perkembangan teknologi yang ada diduni...  Teknik Informatika
#
#        Label                                       judul_tokens  \
# 0        RPL  ancangimplementasisistemdatabasedistribusiorac...
# 1        RPL   aplikasikontrolmonitoringjaringkomputerbasmobile
# 2        RPL  rancangbangunaplikasiproxyserveruntukenkripsik...
# 3  komputasi  sistemdukungputusoptimasijadwalmatakuliahgunar...
# 4  komputasi  sistemaugmentedrealityanimasibendagerakflartoo...
#
#                                       abstrak_tokens
# 0  sisteminformasiakademiksiakadsisteminformasifu...
# 1  jalankoneksijaringkomputerlancargangguharappen...
# 2  webserverperangkatlunakserverberfungsimenerima...
# 3  jadwalkuliahgurukompleksmasalahvariabeltimbang...
# 4  iringkembangteknologiduniamunculteknologiaugme...

# %% [markdown]
# ### Split Data

# %%
from sklearn.model_selection import train_test_split

X = data['abstrak_tokens']
y = data['Label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Feature Extration: TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
countvectorizer = CountVectorizer()
tfidfvectorizer = TfidfVectorizer()

count_wm = countvectorizer.fit_transform(X)
tfidf_wm = tfidfvectorizer.fit_transform(X)

# %%
count_tokens = countvectorizer.get_feature_names_out()
tfidf_tokens = tfidfvectorizer.get_feature_names_out()
df_countvect = pd.DataFrame(data = count_wm.toarray(),columns = count_tokens)
df_tfidfvect = pd.DataFrame(data = tfidf_wm.toarray(),columns = tfidf_tokens)
print("Count Vectorizer\n")
df_countvect
# Out:
# Count Vectorizer
#      ...  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 804                                                  0
# 805                                                  0
# 806                                                  0
# 807                                                  0
# 808                                                  0
#
#      ...  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 804                                                  0
# 805                                                  0
# 806                                                  0
# 807                                                  0
# 808                                                  0
#
#      ...  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 804                                                  0
# 805                                                  0
# 806                                                  0
# 807                                                  0
# 808                                                  0
#
#      ...  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 804                                                  0
# 805                                                  0
# 806                                                  0
# 807                                                  0
# 808                                                  0
#
#      ...  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 804                                                  0
# 805                                                  0
# 806                                                  0
# 807                                                  0
# 808                                                  0
#
#      ...  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 804                                                  0
# 805                                                  0
# 806                                                  0
# 807                                                  0
# 808                                                  0
#
#      ...  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# ...
# 804                                                  0
# 805                                                  0
# 806                                                  0
# 807                                                  0
# 808                                                  0
#
#      ...  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 804                                                  0
# 805                                                  0
# 806                                                  0
# 807                                                  0
# 808                                                  0
#
#      ...
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 804                                                  0
# 805                                                  0
# 806                                                  0
# 807                                                  0
# 808                                                  0
#
# [809 rows x 809 columns]

# %% [markdown]
# PCA

# %%
tfidf_wm.shape
# Out:
# (809, 809)

# %%
# Impor library yang dibutuhkan
from sklearn.decomposition import PCA

# Inisialisasi objek PCA dengan 3 komponen
pca = PCA(n_components=3)

# Melakukan fit transform pada data
X_pca = pca.fit_transform(tfidf_wm.toarray())

# %%
X_pca.shape
# Out:
# (809, 3)

# %% [markdown]
# ### Split Data

# %%
from sklearn.model_selection import train_test_split
training, test = train_test_split(X_pca,test_size=0.2, random_state=1)#Nilai X training dan Nilai X testing
training_label, test_label = train_test_split(y, test_size=0.2, random_state=1)#Nilai Y training dan Nilai Y testing

# %% [markdown]
# #### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

modelKNN = KNeighborsClassifier(n_neighbors=5)
modelKNN.fit(training, training_label)
# Out:
# KNeighborsClassifier()

# %%
test_pred = modelKNN.predict(test)
test_pred
# Out:
# array(['komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'RPL',
#        'komputasi', 'komputasi', 'komputasi', 'RPL', 'komputasi',
#        'komputasi', 'komputasi', 'RPL', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'RPL', 'komputasi', 'komputasi', 'RPL', 'RPL', 'komputasi', 'RPL',
#        'komputasi', 'komputasi', 'RPL', 'komputasi', 'komputasi', 'RPL',
#        'komputasi', 'komputasi', 'komputasi', 'RPL', 'komputasi', 'RPL',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'RPL', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'RPL',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'RPL', 'komputasi', 'komputasi', 'komputasi', 'RPL',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'RPL', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'RPL', 'RPL',
#        'komputasi', 'komputasi', 'komputasi', 'RPL', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'RPL', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'RPL', 'komputasi',
#        'komputasi', 'RPL', 'komputasi', 'PBA', 'komputasi', 'komputasi',
#        'komputasi', 'RPL', 'komputasi', 'komputasi', 'komputasi'],
#       dtype=object)

# %%
accuracy_score(test_label, test_pred)
# Out:
# 0.5925925925925926

# %%
print(classification_report(test_label, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#          PBA       0.00      0.00      0.00        10
#          RPL       0.17      0.10      0.13        41
#    komputasi       0.67      0.83      0.74       111
#
#     accuracy                           0.59       162
#    macro avg       0.28      0.31      0.29       162
# weighted avg       0.50      0.59      0.54       162

# %% [markdown]
# #### Naive Baiyes

# %%
#Model Select
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB
gaussian = GaussianNB()
gaussian.fit(training, training_label)
# Out:
# GaussianNB()

# %%
predict = gaussian.predict(test) 
predict
# Out:
# array(['komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi', 'komputasi', 'komputasi', 'komputasi',
#        'komputasi', 'komputasi'], dtype='<U9')

# %%
accuracy_score(test_label, predict)
# Out:
# 0.6851851851851852

# %%
print(classification_report(test_label, predict))
# Out:
#               precision    recall  f1-score   support
#
#          PBA       0.00      0.00      0.00        10
#          RPL       0.00      0.00      0.00        41
#    komputasi       0.69      1.00      0.81       111
#
#     accuracy                           0.69       162
#    macro avg       0.23      0.33      0.27       162
# weighted avg       0.47      0.69      0.56       162
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
